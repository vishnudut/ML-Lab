# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

data = pd.read_csv('/home/lab3/Downloads/iris-data.csv')
data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
data.head(100)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0             5.100             3.5              1.4             0.2
# 1             4.900             3.0              1.4             0.2
# 2             4.700             3.2              1.3             0.2
# 3             4.600             3.1              1.5             0.2
# 4             5.000             3.6              1.4             0.2
# 5             5.400             3.9              1.7             0.4
# 6             4.600             3.4              1.4             0.3
# 7             5.000             3.4              1.5             NaN
# 8             4.400             2.9              1.4             NaN
# 9             4.900             3.1              1.5             NaN
# 10            5.400             3.7              1.5             NaN
# 11            4.800             3.4              1.6             NaN
# 12            4.800             3.0              1.4             0.1
# 13            5.700             3.0              1.1             0.1
# 14            5.800             4.0              1.2             0.2
# 15            5.700             4.4              1.5             0.4
# 16            5.400             3.9              1.3             0.4
# 17            5.100             3.5              1.4             0.3
# 18            5.700             3.8              1.7             0.3
# 19            5.100             3.8              1.5             0.3
# 20            5.400             3.4              1.7             0.2
# 21            5.100             3.7              1.5             0.4
# 22            4.600             3.6              1.0             0.2
# 23            5.100             3.3              1.7             0.5
# 24            4.800             3.4              1.9             0.2
# 25            5.000             3.0              1.6             0.2
# 26            5.000             3.4              1.6             0.4
# 27            5.200             3.5              1.5             0.2
# 28            5.200             3.4              1.4             0.2
# 29            4.700             3.2              1.6             0.2
# ..              ...             ...              ...             ...
# 70            5.900             3.2              4.8             1.8
# 71            6.100             2.8              4.0             1.3
# 72            6.300             2.5              4.9             1.5
# 73            6.100             2.8              4.7             1.2
# 74            6.400             2.9              4.3             1.3
# 75            6.600             3.0              4.4             1.4
# 76            6.800             2.8              4.8             1.4
# 77            0.067             3.0              5.0             1.7
# 78            0.060             2.9              4.5             1.5
# 79            0.057             2.6              3.5             1.0
# 80            0.055             2.4              3.8             1.1
# 81            0.055             2.4              3.7             1.0
# 82            5.800             2.7              3.9             1.2
# 83            6.000             2.8              5.1             1.6
# 84            5.400             3.0              4.5             1.5
# 85            6.000             3.4              4.5             1.6
# 86            6.700             3.1              4.7             1.5
# 87            6.300             2.3              4.4             1.3
# 88            5.600             3.0              4.1             1.3
# 89            5.500             2.5              4.0             1.3
# 90            5.500             2.6              4.4             1.2
# 91            6.100             3.0              4.6             1.4
# 92            5.800             2.6              4.0             1.2
# 93            5.000             2.3              3.3             1.0
# 94            5.600             2.7              4.2             1.3
# 95            5.700             3.0              4.2             1.2
# 96            5.700             2.9              4.2             1.3
# 97            6.200             2.9              4.3             1.3
# 98            5.100             2.5              3.0             1.1
# 99            5.700             2.8              4.1             1.3
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18     Iris-setossa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 70  Iris-versicolor
# 71  Iris-versicolor
# 72  Iris-versicolor
# 73  Iris-versicolor
# 74  Iris-versicolor
# 75  Iris-versicolor
# 76  Iris-versicolor
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor
# 82  Iris-versicolor
# 83  Iris-versicolor
# 84  Iris-versicolor
# 85  Iris-versicolor
# 86  Iris-versicolor
# 87  Iris-versicolor
# 88  Iris-versicolor
# 89  Iris-versicolor
# 90  Iris-versicolor
# 91  Iris-versicolor
# 92  Iris-versicolor
# 93  Iris-versicolor
# 94  Iris-versicolor
# 95       versicolor
# 96       versicolor
# 97       versicolor
# 98       versicolor
# 99       versicolor
#
# [100 rows x 5 columns]

# %%
data = pd.read_csv('/home/lab3/Downloads/iris-data.csv', na_values=[NA])
data.head(150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-54603bf136d7> in <module>()
# ----> 1 data = pd.read_csv('/home/lab3/Downloads/iris-data.csv', na_values=[NA])
#       2 data.head(150)
#
# NameError: name 'NA' is not defined

# %%
data = pd.read_csv('/home/lab3/Downloads/iris-data.csv', na_values=['NA'])
data.head(150)
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# 12               4.8             3.0              1.4             0.1
# 13               5.7             3.0              1.1             0.1
# 14               5.8             4.0              1.2             0.2
# 15               5.7             4.4              1.5             0.4
# 16               5.4             3.9              1.3             0.4
# 17               5.1             3.5              1.4             0.3
# 18               5.7             3.8              1.7             0.3
# 19               5.1             3.8              1.5             0.3
# 20               5.4             3.4              1.7             0.2
# 21               5.1             3.7              1.5             0.4
# 22               4.6             3.6              1.0             0.2
# 23               5.1             3.3              1.7             0.5
# 24               4.8             3.4              1.9             0.2
# 25               5.0             3.0              1.6             0.2
# 26               5.0             3.4              1.6             0.4
# 27               5.2             3.5              1.5             0.2
# 28               5.2             3.4              1.4             0.2
# 29               4.7             3.2              1.6             0.2
# ..               ...             ...              ...             ...
# 120              6.9             3.2              5.7             2.3
# 121              5.6             2.8              4.9             2.0
# 122              5.6             2.8              6.7             2.0
# 123              6.3             2.7              4.9             1.8
# 124              6.7             3.3              5.7             2.1
# 125              7.2             3.2              6.0             1.8
# 126              6.2             2.8              4.8             1.8
# 127              6.1             3.0              4.9             1.8
# 128              6.4             2.8              5.6             2.1
# 129              7.2             3.0              5.8             1.6
# 130              7.4             2.8              6.1             1.9
# 131              7.9             3.8              6.4             2.0
# 132              6.4             2.8              5.6             2.2
# 133              6.3             2.8              5.1             1.5
# 134              6.1             2.6              5.6             1.4
# 135              7.7             3.0              6.1             2.3
# 136              6.3             3.4              5.6             2.4
# 137              6.4             3.1              5.5             1.8
# 138              6.0             3.0              4.8             1.8
# 139              6.9             3.1              5.4             2.1
# 140              6.7             3.1              5.6             2.4
# 141              6.9             3.1              5.1             2.3
# 142              5.8             2.7              5.1             1.9
# 143              6.8             3.2              5.9             2.3
# 144              6.7             3.3              5.7             2.5
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18     Iris-setossa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data.loc[data['class']=='versicolor','class']='Iris-versicolor'

# %%
data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'Iris-versicolot',
#        'Iris-virginica'], dtype=object)

# %%
# %matplotlib inline

# %%
sb.pairplot(data.dropna(),hue='class')

# %%
data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'Iris-versicolot',
#        'Iris-virginica'], dtype=object)

# %%
data.loc[data['class']=='versicolor','class']='Iris-versicolor'

# %%
data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'Iris-versicolot',
#        'Iris-virginica'], dtype=object)

# %%
csvdata = pd.read_csv('/home/lab3/Downloads/iris-data.csv', na_values=[NA])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f26127e73941> in <module>()
# ----> 1 csvdata = pd.read_csv('/home/lab3/Downloads/iris-data.csv', na_values=[NA])
#
# NameError: name 'NA' is not defined

# %%
('/home/lab3/Downloads/iris-data.csv', na_values=['NA'])
# Out:
#   File "<ipython-input-19-dac367412972>", line 1
#     ('/home/lab3/Downloads/iris-data.csv', na_values=['NA'])
#                                                     ^
# SyntaxError: invalid syntax

# %%
csvdata = pd.read_csv('/home/lab3/Downloads/iris-data.csv', na_values=['NA'])

# %%
csvdata.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
csvdata.loc[data['class']=='versicolor','class']='Iris-versicolor'

# %%
csvdata.loc[csvdata['class']=='versicolor','class']='Iris-versicolor'

# %%
csvdata['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data.loc[data['class']=='versicolor','class']='Iris-versicolor'

# %%
csvdata.loc[csvdata['class']=='versicolor','class']='Iris-versicolor'

# %%
sb.pairplot(csvdata.dropna(),hue='class')

# %%
csvdata = csvdata.loc[csvdata['class'] == 'Iris-setosa','sepal_width_cm'].hist()

# %%
csvdata.loc[(csvdata['sepal_length_cm'].isnull()) | csvdata['sepal_width_cm'].isnull()) | csvdata['petal_length_cm'].isnull()) | csvdata['sepal_width_cm'].isnull())]
# Out:
#   File "<ipython-input-32-3d930815b30f>", line 1
#     csvdata.loc[(csvdata['sepal_length_cm'].isnull()) | csvdata['sepal_width_cm'].isnull()) | csvdata['petal_length_cm'].isnull()) | csvdata['sepal_width_cm'].isnull())]
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
csvdata.loc[(csvdata['sepal_length_cm'].isnull()) | (csvdata['sepal_width_cm'].isnull()) | (csvdata['petal_length_cm'].isnull()) | (csvdata['sepal_width_cm'].isnull())]
# Out:
# Empty DataFrame
# Columns: [sepal_length_cm, sepal_width_cm, petal_length_cm, petal_width_cm, class]
# Index: []

# %%
csvdata

# %%
csvdata

# %%
csvdata
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# 12               4.8             3.0              1.4             0.1
# 13               5.7             3.0              1.1             0.1
# 14               5.8             4.0              1.2             0.2
# 15               5.7             4.4              1.5             0.4
# 16               5.4             3.9              1.3             0.4
# 17               5.1             3.5              1.4             0.3
# 18               5.7             3.8              1.7             0.3
# 19               5.1             3.8              1.5             0.3
# 20               5.4             3.4              1.7             0.2
# 21               5.1             3.7              1.5             0.4
# 22               4.6             3.6              1.0             0.2
# 23               5.1             3.3              1.7             0.5
# 24               4.8             3.4              1.9             0.2
# 25               5.0             3.0              1.6             0.2
# 26               5.0             3.4              1.6             0.4
# 27               5.2             3.5              1.5             0.2
# 28               5.2             3.4              1.4             0.2
# 29               4.7             3.2              1.6             0.2
# ..               ...             ...              ...             ...
# 120              6.9             3.2              5.7             2.3
# 121              5.6             2.8              4.9             2.0
# 122              5.6             2.8              6.7             2.0
# 123              6.3             2.7              4.9             1.8
# 124              6.7             3.3              5.7             2.1
# 125              7.2             3.2              6.0             1.8
# 126              6.2             2.8              4.8             1.8
# 127              6.1             3.0              4.9             1.8
# 128              6.4             2.8              5.6             2.1
# 129              7.2             3.0              5.8             1.6
# 130              7.4             2.8              6.1             1.9
# 131              7.9             3.8              6.4             2.0
# 132              6.4             2.8              5.6             2.2
# 133              6.3             2.8              5.1             1.5
# 134              6.1             2.6              5.6             1.4
# 135              7.7             3.0              6.1             2.3
# 136              6.3             3.4              5.6             2.4
# 137              6.4             3.1              5.5             1.8
# 138              6.0             3.0              4.8             1.8
# 139              6.9             3.1              5.4             2.1
# 140              6.7             3.1              5.6             2.4
# 141              6.9             3.1              5.1             2.3
# 142              5.8             2.7              5.1             1.9
# 143              6.8             3.2              5.9             2.3
# 144              6.7             3.3              5.7             2.5
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18     Iris-setossa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 5 columns]

# %%
csvdata.loc[(csvdata['sepal_length_cm'].isnull()) | (csvdata['sepal_width_cm'].isnull()) | (csvdata['petal_length_cm'].isnull()) | (csvdata['petal_width_cm'].isnull())]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
avg_petal_width = csvdata.loc[csvdata['class'] = 'Iris-setosa','petal_width_cm'].mean()
# Out:
#   File "<ipython-input-40-5602596309aa>", line 1
#     avg_petal_width = csvdata.loc[csvdata['class'] = 'Iris-setosa','petal_width_cm'].mean()
#                                                    ^
# SyntaxError: invalid syntax

# %%
avg_petal_width = csvdata.loc[csvdata['class'] == 'Iris-setosa','petal_width_cm'].mean()

# %%
csvdata.loc[(csvdata['class']=='Iris-setosa') & (csvdata['petal_width_cm'].isnull()), 'petal_width_cm'] = avg_petal_width

# %%
a = csvdata.loc[(csvdata['class']=='Iris-setosa') & (csvdata['petal_width_cm']==avg_petal_width)]

# %%
a.head(10)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5            0.25
# 8               4.4             2.9              1.4            0.25
# 9               4.9             3.1              1.5            0.25
# 10              5.4             3.7              1.5            0.25
# 11              4.8             3.4              1.6            0.25
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

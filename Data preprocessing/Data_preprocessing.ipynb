# %% [markdown]
# # DATA PREPROCESSING
#
# ### V.VISHNU DUT
#
# ### 16BCE1103

# %%
import pandas as pd

data = pd.read_csv('/h.csv')
data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
data.head(100)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0             5.100             3.5              1.4             0.2
# 1             4.900             3.0              1.4             0.2
# 2             4.700             3.2              1.3             0.2
# 3             4.600             3.1              1.5             0.2
# 4             5.000             3.6              1.4             0.2
# 5             5.400             3.9              1.7             0.4
# 6             4.600             3.4              1.4             0.3
# 7             5.000             3.4              1.5             NaN
# 8             4.400             2.9              1.4             NaN
# 9             4.900             3.1              1.5             NaN
# 10            5.400             3.7              1.5             NaN
# 11            4.800             3.4              1.6             NaN
# 12            4.800             3.0              1.4             0.1
# ...

# %%
data = pd.read_csv('/home/lab3/Downloads/iris-data.csv', na_values=['NA'])
data.head(150)
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# ...

# %%
data.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data.loc[data['class']=='versicolor','class']='Iris-versicolor'

# %%
data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'Iris-versicolot',
#        'Iris-virginica'], dtype=object)

# %%
# %matplotlib inline

# %%
sb.pairplot(data.dropna(),hue='class')

# %%
data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'Iris-versicolot',
#        'Iris-virginica'], dtype=object)

# %%
data.loc[data['class']=='versicolor','class']='Iris-versicolor'

# %%
data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'Iris-versicolot',
#        'Iris-virginica'], dtype=object)

# %%
csvdata = pd.read_csv('/home/lab3/Downloads/iris-data.csv', na_values=['NA'])

# %%
csvdata.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
csvdata.loc[data['class']=='versicolor','class']='Iris-versicolor'

# %%
csvdata.loc[csvdata['class']=='versicolor','class']='Iris-versicolor'

# %%
csvdata['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data.loc[data['class']=='versicolor','class']='Iris-versicolor'

# %%
csvdata.loc[csvdata['class']=='versicolor','class']='Iris-versicolor'

# %%
sb.pairplot(csvdata.dropna(),hue='class')

# %%
csvdata = csvdata.loc[csvdata['class'] == 'Iris-setosa','sepal_width_cm'].hist()

# %%
csvdata.loc[(csvdata['sepal_length_cm'].isnull()) | (csvdata['sepal_width_cm'].isnull()) | (csvdata['petal_length_cm'].isnull()) | (csvdata['sepal_width_cm'].isnull())]
# Out:
# Empty DataFrame
# Columns: [sepal_length_cm, sepal_width_cm, petal_length_cm, petal_width_cm, class]
# Index: []

# %%
csvdata

# %%
csvdata

# %%
csvdata
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# ...

# %%
csvdata.loc[(csvdata['sepal_length_cm'].isnull()) | (csvdata['sepal_width_cm'].isnull()) | (csvdata['petal_length_cm'].isnull()) | (csvdata['petal_width_cm'].isnull())]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
avg_petal_width = csvdata.loc[csvdata['class'] == 'Iris-setosa','petal_width_cm'].mean()

# %%
csvdata.loc[(csvdata['class']=='Iris-setosa') & (csvdata['petal_width_cm'].isnull()), 'petal_width_cm'] = avg_petal_width

# %%
a = csvdata.loc[(csvdata['class']=='Iris-setosa') & (csvdata['petal_width_cm']==avg_petal_width)]

# %%
a.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-648fdb0a2dc8> in <module>()
# ----> 1 a.head(10)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### Implementing for my seed dataset

# %%
import pandas as pd
import numpy as np

# %%
col_Names=["area", "perimeter", "compactness", "lengthOfKernel", "widthOfKernel", "asymmetryCoefficient", "lengthOfKernelGroove", "TypeOfWheatSeed"]
dataseed= pd.read_csv("seeds_dataset.csv",names=col_Names, header = None)

# %%
dataseed.head()
# Out:
#     area  perimeter  compactness  lengthOfKernel  widthOfKernel  \
# 0  15.26      14.84       0.8710           5.763          3.312
# 1  14.88      14.57       0.8811           5.554          3.333
# 2  14.29      14.09       0.9050           5.291          3.337
# 3  13.84      13.94       0.8955           5.324          3.379
# 4  16.14      14.99       0.9034           5.658          3.562
#
#    asymmetryCoefficient  lengthOfKernelGroove  TypeOfWheatSeed
# 0                 2.221                 5.220                1
# 1                 1.018                 4.956                1
# 2                 2.699                 4.825                1
# 3                 2.259                 4.805                1
# 4                 1.355                 5.175                1

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
sb.set(style = 'whitegrid', context = 'notebook')

# %%
sb.pairplot(dataseed[col_Names], size = 2.5)
plt.show()
